# %% [markdown]
# <font color="green">*Para iniciar, cree su propia copia de este notebook. File> Save a Copy in Drive*</font>

# %% [markdown]
# #Práctica de MongoDB utilizando pymongo

# %% [markdown]
# A continuación se encuentran las instrucciones para instalar pymongo en notebook en Colab, la configuración de la conexión a un cluster montado en Atlas MongoDB con el fin de realizar consultas en la base de datos test.
#
# **Instrucciones**
#
# Realice cada una de las instrucciones, analice el resultado y realice las consultas propuestas al final.

# %% [markdown]
# ##1. Objetivo
#
# El objetivo de este taller es poder realizar consultas a una base de datos MongoDB montada en Atlas, utilizando pymongo

# %% [markdown]
# ##2. Configuración pymongo

# %% [markdown]
# Pymongo es una librería de Python para poder conectarnos a una base de datos MongoDB. En este ejemplo vamos a ver cómo conectarnos desde Python a MongoDB.

# %%
# !python --version
# Out:
# Python 3.10.11

# %% [markdown]
# Primero vamos a instalar **pymongo**.
# Pymongo es una biblioteca de Python utilizada para interactuar con bases de datos MongoDB, permitiendo insertar, actualizar, eliminar y consultar datos.

# %%
# !pip install pymongo
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pymongo
#   Downloading pymongo-4.3.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (492 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 492.9/492.9 kB 4.4 MB/s eta 0:00:00
# Collecting dnspython<3.0.0,>=1.16.0
#   Downloading dnspython-2.3.0-py3-none-any.whl (283 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 283.7/283.7 kB 18.3 MB/s eta 0:00:00
# Installing collected packages: dnspython, pymongo
# Successfully installed dnspython-2.3.0 pymongo-4.3.3

# %% [markdown]
# el comando `!pip install` utiliza **pip** que es un administrador de paquetes de software para Python que facilita la instalación y administración de paquetes de terceros

# %%
import pymongo

# %% [markdown]
# ##3. Configurando la conexión a la base de datos test en el cluster en Atlas MongoDB

# %% [markdown]
# Para configuración se usará la función `MongoClient()` que crea una instancia del cliente que se conecta a la base de datos y toma una cadena de conexión como parámetro.

# %%
# Trying 3.6+ connection string
client = pymongo.MongoClient(
    "mongodb+srv://infrati:infrati@cluster0.v5rih5b.mongodb.net/?retryWrites=true&w=majority")
db = client.infrati

# %% [markdown]
# La primera línea crea una instancia del cliente MongoClient que se conecta a la base de datos, tomando como parámetro una cadena de conexión que contiene la dirección de MongoDB y las credenciales necesarias para acceder a la base de datos. En la segunda línea, se selecciona la base de datos "infrati" en el clúster, y se almacena en la variable "db".

# %%
db
# Out:
# Database(MongoClient(host=['ac-vv4a0mx-shard-00-01.v5rih5b.mongodb.net:27017', 'ac-vv4a0mx-shard-00-02.v5rih5b.mongodb.net:27017', 'ac-vv4a0mx-shard-00-00.v5rih5b.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, retrywrites=True, w='majority', authsource='admin', replicaset='atlas-mrr86e-shard-0', tls=True), 'infrati')

# %% [markdown]
# `db` es un objeto a través del cual se pueden realizar operaciones en la base de datos test como la inserción, actualización y consulta de datos.

# %% [markdown]
# ##Inserción de un documento
#
# Modifique la siguiente instrucción, antes de ejecutarla.  Coloque sus propios datos antes de realizar la inserción del documento.

# %%
#modifique los datos antes de insertar el documento

db.users.insert_one({'nombre':'Monica','apellido':'Rojas','edad':28, 'genero':'femenino'})

# %% [markdown]
# Esta línea de código inserta un nuevo documento en una colección llamada `users`.
# En este caso, se está insertando un documento con los campos "nombre", "apellido", "edad" y "género" y sus respectivos valores

# %% [markdown]
# ##Consultas

# %% [markdown]
# Consultar todos los documentos en la colección *users*

# %%
list(db.users.find())
# Out:
# [{'_id': ObjectId('6346eb8c9194c3e70cca107d'),
#   'nombre': 'Leonardo',
#   'apellido': 'Jurado',
#   'edad': 44,
#   'estatura': '1.80'},
#  {'_id': ObjectId('6346eb8c9194c3e70cca107f'),
#   'nombre': 'Alejandro',
#   'apellido': 'Sanchez',
#   'edad': 10,
#   'estatura': '1.40'},
#  {'_id': ObjectId('6346eb8c9194c3e70cca1080'),
#   'nombre': 'Lucia',
#   'apellido': 'Cardenas',
#   'edad': 28,
#   'estatura': '1.68'},
#  {'_id': ObjectId('6346eb8c9194c3e70cca107c'),
#   'nombre': 'Mario',
#   'apellido': 'Restrepo',
#   'edad': 78},
#  {'_id': ObjectId('6346eb8c9194c3e70cca1079'),
#   'nombre': 'Monica',
#   'apellido': 'Rojas',
#   'genero': 'femenino',
#   'edad': 43,
#   'estatura': '1.60'},
#  {'_id': ObjectId('6346eb8c9194c3e70cca107e'),
#   'nombre': 'Camila',
#   'apellido': 'Jurado',
#   'genero': 'femenino',
#   'edad': 12,
#   'estatura': '1.50'},
#  {'_id': ObjectId('6346eb8c9194c3e70cca1081'),
#   'nombre': 'Fernando',
#   'apellido': 'Collazos',
#   'edad': 45,
#   'estatura': '1.82',
#   'genero': 'Masculino'},
#  {'_id': ObjectId('6346eb8c9194c3e70cca107a'),
#   'nombre': 'Maria',
#   'apellido': 'Andrade',
#   'edad': 18,
#   'estatura': '1.50'}]

# %% [markdown]
# Luego imprimimos el contenido de la colección `users`

# %% [markdown]
# **Selección**
# Consultar los usuarios con edad igual a 28.

# %%
list(db.users.find({'edad':28}))
# Out:
# [{'_id': ObjectId('6346eb8c9194c3e70cca1080'),
#   'nombre': 'Lucia',
#   'apellido': 'Cardenas',
#   'edad': 28,
#   'estatura': '1.68'}]

# %%
list(db.users.find({'edad':28}))

# %% [markdown]
# **Consultar un solo documento**

# %%
db.users.find_one()
# Out:
# {'_id': ObjectId('6346eb8c9194c3e70cca107d'),
#  'nombre': 'Leonardo',
#  'apellido': 'Jurado',
#  'edad': 44,
#  'estatura': '1.80'}

# %% [markdown]
# **Proyección**
#
# Consultar los apellidos de todos los usuarios

# %%
list(db.users.find({},{'apellido':1}))
# Out:
# [{'_id': ObjectId('6346eb8c9194c3e70cca107d'), 'apellido': 'Jurado'},
#  {'_id': ObjectId('6346eb8c9194c3e70cca107f'), 'apellido': 'Sanchez'},
#  {'_id': ObjectId('6346eb8c9194c3e70cca1080'), 'apellido': 'Cardenas'},
#  {'_id': ObjectId('6346eb8c9194c3e70cca107c'), 'apellido': 'Restrepo'},
#  {'_id': ObjectId('6346eb8c9194c3e70cca1079'), 'apellido': 'Rojas'},
#  {'_id': ObjectId('6346eb8c9194c3e70cca107e'), 'apellido': 'Jurado'},
#  {'_id': ObjectId('6346eb8c9194c3e70cca1081'), 'apellido': 'Collazos'},
#  {'_id': ObjectId('6346eb8c9194c3e70cca107a'), 'apellido': 'Andrade'}]

# %% [markdown]
# **Proyección y selección**
#
# Consultar los usuarios nombre Monica y mostrar el apellido

# %%
list(db.users.find({'nombre':'Monica'},{'apellido':1}))
# Out:
# [{'_id': ObjectId('6346eb8c9194c3e70cca1079'), 'apellido': 'Rojas'}]

# %% [markdown]
# **Operadores**
#
# Consulte todos los operadores en [Operators MongoDB](https://www.mongodb.com/docs/manual/reference/operator/query/)

# %% [markdown]
# **Diferente**
#
# Mostrar los usuarios con nombre diferente a Mario

# %%
#se crea una variable usuario para recibir el resultado de la consulta
usuario = db.users.find({'nombre':{'$ne':'Mario'}})

# %%
#se muestra 
list(usuario)
# Out:
# [{'_id': ObjectId('6346eb8c9194c3e70cca107f'),
#   'nombre': 'Alejandro',
#   'apellido': 'Sanchez',
#   'edad': 10,
#   'estatura': '1.40'},
#  {'_id': ObjectId('6346eb8c9194c3e70cca107e'),
#   'nombre': 'Camila',
#   'apellido': 'Jurado',
#   'genero': 'femenino',
#   'edad': 12,
#   'estatura': '1.50'},
#  {'_id': ObjectId('6346eb8c9194c3e70cca1081'),
#   'nombre': 'Fernando',
#   'apellido': 'Collazos',
#   'edad': 45,
#   'estatura': '1.82',
#   'genero': 'Masculino'},
#  {'_id': ObjectId('6346eb8c9194c3e70cca107d'),
#   'nombre': 'Leonardo',
#   'apellido': 'Jurado',
#   'edad': 44,
#   'estatura': '1.80'},
#  {'_id': ObjectId('6346eb8c9194c3e70cca1080'),
#   'nombre': 'Lucia',
#   'apellido': 'Cardenas',
#   'edad': 28,
#   'estatura': '1.68'},
#  {'_id': ObjectId('6346eb8c9194c3e70cca107a'),
#   'nombre': 'Maria',
#   'apellido': 'Andrade',
#   'edad': 18,
#   'estatura': '1.50'},
#  {'_id': ObjectId('6346eb8c9194c3e70cca1079'),
#   'nombre': 'Monica',
#   'apellido': 'Rojas',
#   'genero': 'femenino',
#   'edad': 43,
#   'estatura': '1.60'}]

# %% [markdown]
# **Usuarios con edad mayor a 20**

# %%
list(db.users.find({'edad':{'$gte':20}}))
# Out:
# [{'_id': ObjectId('6346eb8c9194c3e70cca1080'),
#   'nombre': 'Lucia',
#   'apellido': 'Cardenas',
#   'edad': 28,
#   'estatura': '1.68'},
#  {'_id': ObjectId('6346eb8c9194c3e70cca1079'),
#   'nombre': 'Monica',
#   'apellido': 'Rojas',
#   'genero': 'femenino',
#   'edad': 43,
#   'estatura': '1.60'},
#  {'_id': ObjectId('6346eb8c9194c3e70cca107d'),
#   'nombre': 'Leonardo',
#   'apellido': 'Jurado',
#   'edad': 44,
#   'estatura': '1.80'},
#  {'_id': ObjectId('6346eb8c9194c3e70cca1081'),
#   'nombre': 'Fernando',
#   'apellido': 'Collazos',
#   'edad': 45,
#   'estatura': '1.82',
#   'genero': 'Masculino'},
#  {'_id': ObjectId('6346eb8c9194c3e70cca107c'),
#   'nombre': 'Mario',
#   'apellido': 'Restrepo',
#   'edad': 78}]

# %% [markdown]
# **Consulta con el operador OR**
#
# Mostrar los usuarios con nombre Mario o apellido Rojas

# %%
list(db.users.find({'$or':[{nombre:'Mario'},{'apellido':'Rojas'}]}))
# Out:
# [{'_id': ObjectId('6346eb8c9194c3e70cca107c'),
#   'nombre': 'Mario',
#   'apellido': 'Restrepo',
#   'edad': 78},
#  {'_id': ObjectId('6346eb8c9194c3e70cca1079'),
#   'nombre': 'Monica',
#   'apellido': 'Rojas',
#   'genero': 'femenino',
#   'edad': 43,
#   'estatura': '1.60'}]

# %% [markdown]
# **Mostrar los generos distintos**

# %%
db.users.distinct('genero')
# Out:
# ['Masculino', 'femenino']

# %% [markdown]
# **Consultas**
#
# Practica realizando las siguientes consultas

# %% [markdown]
# 1.   Consulte todos los documentos

# %% [markdown]
# 2.   Muestre los nombres, apellidos de todos los usuarios, sin mostrar el campo *_id*

# %% [markdown]
# 3.   Muestre los nombres y apellidos de los usuarios mayores de 18 años

# %% [markdown]
# 4.   Muestre los nombres y apellidos de las usuarias menores de 40 años

# %% [markdown]
# 5.   Muestre los nombres y apellidos de las usuarios que no se identifican con  género Masculino o femenino.
